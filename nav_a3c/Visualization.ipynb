# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
from vis import vis_paths

# %%
positions = []
for a in range(40, 49):
    with open ('./positions/%s' % str(a + 1), 'rb') as fp:
        positions.append(pickle.load(fp))

# %%
vis_paths(positions)

# %%
positions
# Out:
# [[[-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.1500244140625, -2.585880756378174, 192.41000366210938],
#   [-634.6676635742188, -2.5706582069396973, 194.34185791015625],
#   [-634.6676635742188, -2.5706582069396973, 194.34185791015625],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
#   [-634.77099609375, -2.5547239780426025, 196.36456298828125],
# ...
